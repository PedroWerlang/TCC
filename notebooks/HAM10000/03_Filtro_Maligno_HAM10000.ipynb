# %%
from google.colab import drive
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

drive.mount('/content/drive')

# !rm -rf /content/dataset_maligno_ham/
# !unzip -q "/content/drive/MyDrive/Colab Notebooks/TCC/Datasets/Dataset_Filtro_Maligno_HAM_10000.zip" -d "/content/dataset_maligno_ham/"

base_dir = '/content/dataset_maligno_ham/'
if 'Dataset_Filtro_Maligno_HAM_10000' in os.listdir(base_dir):
    base_dir = os.path.join(base_dir, 'Dataset_Filtro_Maligno_HAM_10000')

train_dir = os.path.join(base_dir, 'Train')
val_dir = os.path.join(base_dir, 'Val')
test_dir = os.path.join(base_dir, 'Test')

caminho_salvamento = "/content/drive/MyDrive/Colab Notebooks/TCC/Modelos/ResNet50_Filtro_Maligno_HAM10000.keras"
os.makedirs(os.path.dirname(caminho_salvamento), exist_ok=True)

BATCH_SIZE = 32
IMG_SIZE = (224, 224)
NUM_CLASSES = 3

train_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input,
    rotation_range=40, width_shift_range=0.2, height_shift_range=0.2,
    horizontal_flip=True, vertical_flip=True, fill_mode='nearest'
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input
)

train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical'
)
val_generator = val_test_datagen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)
test_generator = val_test_datagen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])

callbacks_f1 = [
    ModelCheckpoint(caminho_salvamento, save_best_only=True, monitor="val_loss"),
    EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2)
]

model.fit(train_generator, epochs=10, validation_data=val_generator, callbacks=callbacks_f1)

base_model.trainable = True
model.compile(optimizer=Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

callbacks_f2 = [
    ModelCheckpoint(caminho_salvamento, save_best_only=True, monitor="val_loss"),
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3)
]

model.fit(train_generator, epochs=15, validation_data=val_generator, callbacks=callbacks_f2)

model_final = load_model(caminho_salvamento)
test_generator.reset()
previsoes = model_final.predict(test_generator)
classes_preditas = np.argmax(previsoes, axis=1)
classes_reais = test_generator.classes
nomes_classes = list(test_generator.class_indices.keys())

print("\n--- Relatório de Classificação ---")
print(classification_report(classes_reais, classes_preditas, target_names=nomes_classes))

matriz_absoluta = confusion_matrix(classes_reais, classes_preditas)
matriz_porcentagem = matriz_absoluta.astype('float') / (matriz_absoluta.sum(axis=1)[:, np.newaxis] + 1e-9)

labels = [f"{v1}\n({v2:.1%})" for v1, v2 in zip(matriz_absoluta.flatten(), matriz_porcentagem.flatten())]
labels = np.asarray(labels).reshape(matriz_absoluta.shape)

plt.figure(figsize=(8, 6))
sns.heatmap(matriz_absoluta, annot=labels, fmt='', cmap='YlGn', xticklabels=nomes_classes, yticklabels=nomes_classes, annot_kws={"size": 12})
plt.title('Matriz de Confusão - Especialista Maligno HAM10000', fontsize=14, fontweight='bold')
plt.ylabel('True Label', fontsize=12)
plt.xlabel('Predicted Label', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Mounted at /content/drive
# Base do Filtro Maligno HAM10000 extraída com sucesso!
#
# Configurando geradores de imagens...
# Found 1365 images belonging to 3 classes.
# Found 202 images belonging to 3 classes.
# Found 387 images belonging to 3 classes.
#
# Carregando ResNet50 e configurando FASE 1...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Iniciando Fase 1: Aquecimento das camadas para o especialista HAM10000...
# Epoch 1/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.6601 - loss: 0.9379 - val_accuracy: 0.7327 - val_loss: 0.6695 - learning_rate: 0.0010
# Epoch 2/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 32s 739ms/step - accuracy: 0.7326 - loss: 0.6103 - val_accuracy: 0.7624 - val_loss: 0.5429 - learning_rate: 0.0010
# Epoch 3/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 30s 692ms/step - accuracy: 0.7538 - loss: 0.5674 - val_accuracy: 0.7475 - val_loss: 0.5730 - learning_rate: 0.0010
# Epoch 4/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 30s 695ms/step - accuracy: 0.7634 - loss: 0.5663 - val_accuracy: 0.7525 - val_loss: 0.5360 - learning_rate: 0.0010
# Epoch 5/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 29s 683ms/step - accuracy: 0.7604 - loss: 0.5154 - val_accuracy: 0.7772 - val_loss: 0.5682 - learning_rate: 0.0010
# Epoch 6/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 29s 667ms/step - accuracy: 0.8132 - loss: 0.4709 - val_accuracy: 0.7525 - val_loss: 0.5710 - learning_rate: 0.0010
# Epoch 7/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 29s 678ms/step - accuracy: 0.7956 - loss: 0.4614 - val_accuracy: 0.7624 - val_loss: 0.5521 - learning_rate: 2.0000e-04
# Epoch 8/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 30s 700ms/step - accuracy: 0.8205 - loss: 0.4199 - val_accuracy: 0.7723 - val_loss: 0.5597 - learning_rate: 2.0000e-04
#
# Iniciando FASE 2: Lapidação Profunda (100% Descongelado)...
# Epoch 1/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 132s 2s/step - accuracy: 0.7026 - loss: 0.6566 - val_accuracy: 0.8069 - val_loss: 0.5104 - learning_rate: 1.0000e-05
# Epoch 2/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 41s 942ms/step - accuracy: 0.7817 - loss: 0.5360 - val_accuracy: 0.8069 - val_loss: 0.4933 - learning_rate: 1.0000e-05
# Epoch 3/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 41s 961ms/step - accuracy: 0.8132 - loss: 0.4584 - val_accuracy: 0.8168 - val_loss: 0.4746 - learning_rate: 1.0000e-05
# Epoch 4/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 40s 941ms/step - accuracy: 0.8330 - loss: 0.4073 - val_accuracy: 0.8366 - val_loss: 0.4698 - learning_rate: 1.0000e-05
# Epoch 5/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 40s 934ms/step - accuracy: 0.8527 - loss: 0.3558 - val_accuracy: 0.8416 - val_loss: 0.4665 - learning_rate: 1.0000e-05
# Epoch 6/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 43s 968ms/step - accuracy: 0.8615 - loss: 0.3300 - val_accuracy: 0.8465 - val_loss: 0.4441 - learning_rate: 1.0000e-05
# Epoch 7/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 41s 953ms/step - accuracy: 0.8916 - loss: 0.2955 - val_accuracy: 0.8564 - val_loss: 0.4345 - learning_rate: 1.0000e-05
# Epoch 8/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 40s 937ms/step - accuracy: 0.8960 - loss: 0.2760 - val_accuracy: 0.8416 - val_loss: 0.4565 - learning_rate: 1.0000e-05
# Epoch 9/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 35s 817ms/step - accuracy: 0.9004 - loss: 0.2485 - val_accuracy: 0.8614 - val_loss: 0.4306 - learning_rate: 1.0000e-05
# Epoch 10/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 39s 914ms/step - accuracy: 0.9187 - loss: 0.2200 - val_accuracy: 0.8465 - val_loss: 0.4744 - learning_rate: 1.0000e-05
# Epoch 11/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 33s 764ms/step - accuracy: 0.9201 - loss: 0.2145 - val_accuracy: 0.8515 - val_loss: 0.4373 - learning_rate: 1.0000e-05
# Epoch 12/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 33s 759ms/step - accuracy: 0.9245 - loss: 0.2100 - val_accuracy: 0.8614 - val_loss: 0.4423 - learning_rate: 1.0000e-05
# Epoch 13/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 35s 798ms/step - accuracy: 0.9355 - loss: 0.1841 - val_accuracy: 0.8564 - val_loss: 0.4434 - learning_rate: 2.0000e-06
# Epoch 14/15
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 33s 765ms/step - accuracy: 0.9348 - loss: 0.1795 - val_accuracy: 0.8564 - val_loss: 0.4453 - learning_rate: 2.0000e-06
#
# Carregando o melhor modelo especialista para avaliação...
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 682ms/step
#
# =======================================================
# RESULTADOS - ESPECIALISTA MALIGNO HAM10000 (akiec, bcc, mel)
# =======================================================
#               precision    recall  f1-score   support
#
#        akiec       0.78      0.30      0.43        60
#          bcc       0.84      0.75      0.79       111
#          mel       0.80      0.98      0.88       216
#
#     accuracy                           0.81       387
#    macro avg       0.81      0.68      0.70       387
# weighted avg       0.81      0.81      0.79       387
