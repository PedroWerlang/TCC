# %%
from google.colab import drive
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

drive.mount('/content/drive')

# !rm -rf /content/dataset_maligno/
# !unzip -q "/content/drive/MyDrive/Colab Notebooks/TCC/Datasets/Dataset_Filtro_Maligno_ISIC_2019.zip" -d "/content/dataset_maligno/"

base_dir = '/content/dataset_maligno/'
if 'Dataset_Filtro_Maligno_ISIC_2019' in os.listdir(base_dir):
    base_dir = os.path.join(base_dir, 'Dataset_Filtro_Maligno_ISIC_2019')

train_dir = os.path.join(base_dir, 'Train')
val_dir = os.path.join(base_dir, 'Val')
test_dir = os.path.join(base_dir, 'Test')

caminho_salvamento = "/content/drive/MyDrive/Colab Notebooks/TCC/Modelos/ResNet50_Filtro_Maligno_ISIC_2019.keras"
os.makedirs(os.path.dirname(caminho_salvamento), exist_ok=True)

BATCH_SIZE = 32
IMG_SIZE = (224, 224)
NUM_CLASSES = 4

train_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input,
    rotation_range=40, width_shift_range=0.2, height_shift_range=0.2,
    horizontal_flip=True, vertical_flip=True, fill_mode='nearest'
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input
)

train_generator = train_datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical'
)
val_generator = val_test_datagen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)
test_generator = val_test_datagen.flow_from_directory(
    test_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)

base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer=Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])

callbacks_f1 = [
    ModelCheckpoint(caminho_salvamento, save_best_only=True, monitor="val_loss"),
    EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2)
]

model.fit(train_generator, epochs=10, validation_data=val_generator, callbacks=callbacks_f1)

base_model.trainable = True
model.compile(optimizer=Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

callbacks_f2 = [
    ModelCheckpoint(caminho_salvamento, save_best_only=True, monitor="val_loss"),
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3)
]

model.fit(train_generator, epochs=15, validation_data=val_generator, callbacks=callbacks_f2)

model_final = load_model(caminho_salvamento)
test_generator.reset()
previsoes = model_final.predict(test_generator)
classes_preditas = np.argmax(previsoes, axis=1)
classes_reais = test_generator.classes
nomes_classes = list(test_generator.class_indices.keys())

print("\n--- Relatório de Classificação ---")
print(classification_report(classes_reais, classes_preditas, target_names=nomes_classes))

matriz_absoluta = confusion_matrix(classes_reais, classes_preditas)
matriz_porcentagem = matriz_absoluta.astype('float') / (matriz_absoluta.sum(axis=1)[:, np.newaxis] + 1e-9)

labels = [f"{v1}\n({v2:.1%})" for v1, v2 in zip(matriz_absoluta.flatten(), matriz_porcentagem.flatten())]
labels = np.asarray(labels).reshape(matriz_absoluta.shape)

plt.figure(figsize=(8, 6))
sns.heatmap(matriz_absoluta, annot=labels, fmt='', cmap='Oranges', xticklabels=nomes_classes, yticklabels=nomes_classes, annot_kws={"size": 12})
plt.title('Matriz de Confusão - Especialista Maligno ISIC 2019', fontsize=14, fontweight='bold')
plt.ylabel('True Label', fontsize=12)
plt.xlabel('Predicted Label', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Mounted at /content/drive
# Base do Filtro Maligno extraída com sucesso!
#
# Configurando geradores de imagens...
# Found 6288 images belonging to 4 classes.
# Found 982 images belonging to 4 classes.
# Found 2070 images belonging to 4 classes.
#
# Carregando ResNet50 e configurando FASE 1...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Iniciando Fase 1: Aquecimento das camadas especializadas...
# Epoch 1/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 208s 983ms/step - accuracy: 0.6703 - loss: 0.9014 - val_accuracy: 0.6833 - val_loss: 0.7674 - learning_rate: 0.0010
# Epoch 2/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 171s 868ms/step - accuracy: 0.7018 - loss: 0.7732 - val_accuracy: 0.7332 - val_loss: 0.7151 - learning_rate: 0.0010
# Epoch 3/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 168s 854ms/step - accuracy: 0.7176 - loss: 0.7344 - val_accuracy: 0.7373 - val_loss: 0.7013 - learning_rate: 0.0010
# Epoch 4/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 164s 832ms/step - accuracy: 0.7168 - loss: 0.7247 - val_accuracy: 0.7373 - val_loss: 0.7023 - learning_rate: 0.0010
# Epoch 5/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 163s 827ms/step - accuracy: 0.7331 - loss: 0.6811 - val_accuracy: 0.7383 - val_loss: 0.6855 - learning_rate: 0.0010
# Epoch 6/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 168s 850ms/step - accuracy: 0.7451 - loss: 0.6680 - val_accuracy: 0.7505 - val_loss: 0.6773 - learning_rate: 0.0010
# Epoch 7/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 165s 836ms/step - accuracy: 0.7545 - loss: 0.6487 - val_accuracy: 0.7424 - val_loss: 0.6937 - learning_rate: 0.0010
# Epoch 8/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 168s 852ms/step - accuracy: 0.7470 - loss: 0.6523 - val_accuracy: 0.7505 - val_loss: 0.6771 - learning_rate: 0.0010
# Epoch 9/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 165s 837ms/step - accuracy: 0.7492 - loss: 0.6393 - val_accuracy: 0.7363 - val_loss: 0.6920 - learning_rate: 0.0010
# Epoch 10/10
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 167s 850ms/step - accuracy: 0.7562 - loss: 0.6366 - val_accuracy: 0.7342 - val_loss: 0.6829 - learning_rate: 0.0010
#
# Iniciando FASE 2: Lapidação Profunda (100% Descongelado)...
# Epoch 1/15
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 285s 1s/step - accuracy: 0.6931 - loss: 0.8619 - val_accuracy: 0.7556 - val_loss: 0.6693 - learning_rate: 1.0000e-05
# Epoch 2/15
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 190s 962ms/step - accuracy: 0.7581 - loss: 0.6353 - val_accuracy: 0.7627 - val_loss: 0.6478 - learning_rate: 1.0000e-05
# Epoch 3/15
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 188s 955ms/step - accuracy: 0.7837 - loss: 0.5725 - val_accuracy: 0.7515 - val_loss: 0.6386 - learning_rate: 1.0000e-05
# Epoch 4/15
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 187s 947ms/step - accuracy: 0.7961 - loss: 0.5351 - val_accuracy: 0.7536 - val_loss: 0.6449 - learning_rate: 1.0000e-05
# Epoch 5/15
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 202s 948ms/step - accuracy: 0.8139 - loss: 0.4868 - val_accuracy: 0.7617 - val_loss: 0.6536 - learning_rate: 1.0000e-05
# Epoch 6/15
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 182s 922ms/step - accuracy: 0.8228 - loss: 0.4512 - val_accuracy: 0.7739 - val_loss: 0.6644 - learning_rate: 1.0000e-05
# Epoch 7/15
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 184s 934ms/step - accuracy: 0.8357 - loss: 0.4216 - val_accuracy: 0.7627 - val_loss: 0.6778 - learning_rate: 2.0000e-06
# Epoch 8/15
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 183s 926ms/step - accuracy: 0.8405 - loss: 0.4099 - val_accuracy: 0.7637 - val_loss: 0.6853 - learning_rate: 2.0000e-06
#
# Carregando o melhor modelo especialista para avaliação...
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 36s 491ms/step
#
# =======================================================
# RESULTADOS - ESPECIALISTA MALIGNO (AK, BCC, MEL, SCC)
# =======================================================
#               precision    recall  f1-score   support
#
#           AK       0.55      0.44      0.49       179
#          BCC       0.75      0.81      0.78       626
#          MEL       0.83      0.95      0.89      1087
#          SCC       0.60      0.05      0.09       178
#
#     accuracy                           0.79      2070
#    macro avg       0.68      0.56      0.56      2070
# weighted avg       0.76      0.79      0.75      2070
